# %%
import pickle, copy, os, re, datetime, io
import pandas as pd
import numpy as np
from collections import Counter, deque, defaultdict
from datetime import timedelta as td
from datetime import datetime as dt

import matplotlib.pyplot as plt
import matplotlib as mpl

import tarfile
import glob
import boto3
import botocore
import sagemaker
import json

from io import StringIO, BytesIO

s3_client = boto3.client('s3')
s3_resource = boto3.resource('s3')
sm_client = boto3.client('sagemaker', config = botocore.config.Config())

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.layers import IntegerLookup, Normalization, StringLookup
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor

from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder, LabelEncoder
# Out:
# 2023-03-08 12:55:45.454936: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def encode_features(col):
    le = LabelEncoder()
    # print(c, len(set(col)))
    le.fit(col)
    col = le.transform(col)
    return col

def standardize_features(col):
    return (col-np.mean(col))/(np.std(col))

def normalize_features(col):
    return (col-min(col))/(max(col)-min(col))

class PrintDot(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    #if epoch == 0:
    print(str(epoch)+' ',end='')

def create_sagemaker_model(name, model_data_uri, instance_type):
    image_uri = sagemaker.image_uris.retrieve(
        framework='Tensorflow',
        version='2.9.2',
        instance_type=instance_type,
        region='us-west-2',
        py_version='py3',
        image_scope='inference'
    )
    sm_client.create_model(
        ModelName=name,
        ExecutionRoleArn=params['sm_role'],
        PrimaryContainer={
            'ModelDataUrl': model_data_uri,
            'Image': image_uri
        }
    )
    
def save_and_package_model(model_assets, path, bucket='hwm-nba', name=None, sagemaker_name=None,
                           upload='sagemaker', instance_type='ml.c5.large', key_data=None):
    if name is None:
        name = model_assets['name']
    if sagemaker_name is None:
        sagemaker_name = name
    tar_name = 'model.tar.gz'
    local_path = os.path.join(path, name, tar_name)
    tf.keras.models.save_model(model_assets['model'], os.path.join(path, name, '00001'))
    model_assets['history'].to_csv(os.path.join(path, name, 'history.csv'), index=False)
    tar = tarfile.open(os.path.join(path, name, tar_name), 'w:gz')
    for file_name in glob.glob(os.path.join(path, name, '*')):
        print('Adding %s...' % file_name)
        tar.add(file_name, os.path.basename(file_name))
    tar.close()
    if key_data is not None:
        key_dict = {'key': str([int(np.round(p)) for p in model_assets['model'].predict(key_data).squeeze()])}
        pd.DataFrame(key_data).to_csv(os.path.join(path, name, 'key_data.csv'), index=False)
        with open(os.path.join(path, name, 'key.json'), 'w') as outfile:
            json.dump(key_dict, outfile)
    if upload in('s3','sagemaker'):
        s3_path = os.path.join('models', name, tar_name)
        s3_full_uri = os.path.join('s3://', bucket, s3_path)
        s3_client.upload_file(local_path, bucket, s3_path)
        if key_data is not None:
            s3_client.upload_file(os.path.join(path, name, 'key_data.csv'), bucket, os.path.join('models', name, 'key_data.csv'))
            s3_client.upload_file(os.path.join(path, name, 'key.json'), bucket, os.path.join('models', name, 'key.json'))
        s3_client.upload_file(os.path.join(path, name, 'history.csv'), bucket, os.path.join('models', name, 'history.csv'))
        if upload == 'sagemaker':
            create_sagemaker_model(sagemaker_name, s3_full_uri, instance_type)

# %% [markdown]
# #####
# ##### **LOAD DATA**

# %%
# games_final = pd.read_csv('../data/processed/games_final.csv')
with open('../data/processed/games_final.pickle', 'rb') as f: games_final = pickle.load(f)

# %%
games_final[-100:-80]
# Out:
#              date away   as home   hs  ot            detail_path game_type  \
# 36239  2023-02-27  MIA  101  PHI   99   0  mia-vs-phi-0022200920   regular
# 36240  2023-02-27  ORL  101  NOP   93   0  orl-vs-nop-0022200922   regular
# 36241  2023-02-28  CHI   98  TOR  104   0  chi-vs-tor-0022200925   regular
# 36242  2023-02-28  DEN  133  HOU  112   0  den-vs-hou-0022200926   regular
# 36243  2023-02-28  IND  124  DAL  122   0  ind-vs-dal-0022200929   regular
# 36244  2023-02-28  LAL  109  MEM  121   0  lal-vs-mem-0022200927   regular
# 36245  2023-02-28  MIL  118  BKN  104   0  mil-vs-bkn-0022200924   regular
# 36246  2023-02-28  MIN  108  LAC  101   0  min-vs-lac-0022200932   regular
# 36247  2023-02-28  POR  105  GSW  123   0  por-vs-gsw-0022200931   regular
# 36248  2023-02-28  SAC  123  OKC  117   0  sac-vs-okc-0022200928   regular
# 36249  2023-02-28  SAS  102  UTA   94   0  sas-vs-uta-0022200930   regular
# 36250  2023-02-28  WAS  119  ATL  116   0  was-vs-atl-0022200923   regular
# 36251  2023-03-01  BKN  118  NYK  142   0  bkn-vs-nyk-0022200937   regular
# 36252  2023-03-01  CHI  117  DET  115   0  chi-vs-det-0022200934   regular
# 36253  2023-03-01  CLE  113  BOS  117   0  cle-vs-bos-0022200935   regular
# 36254  2023-03-01  LAL  123  OKC  117   0  lal-vs-okc-0022200940   regular
# 36255  2023-03-01  MEM  113  HOU   99   0  mem-vs-hou-0022200938   regular
# 36256  2023-03-01  NOP  121  POR  110   0  nop-vs-por-0022200941   regular
# 36257  2023-03-01  ORL  117  MIL  139   0  orl-vs-mil-0022200939   regular
# 36258  2023-03-01  PHI  119  MIA   96   0  phi-vs-mia-0022200936   regular
#
#        game_subtype  diff  ... away_standing_losses away_standing_wins_home  \
# 36239             0     2  ...                 31.0                    19.0
# 36240             0     8  ...                 34.0                    17.0
# 36241             0     6  ...                 32.0                    19.0
# 36242             0    21  ...                 20.0                    28.0
# 36243             0     2  ...                 34.0                    19.0
# 36244             0    12  ...                 32.0                    16.0
# 36245             0    14  ...                 18.0                    26.0
# 36246             0     7  ...                 30.0                    22.0
# 36247             0    18  ...                 32.0                    17.0
# 36248             0     6  ...                 27.0                    18.0
# 36249             0     8  ...                 45.0                    11.0
# 36250             0     3  ...                 32.0                    14.0
# 36251             0    24  ...                 26.0                    19.0
# 36252             0     2  ...                 33.0                    19.0
# 36253             0     4  ...                 26.0                    26.0
# 36254             0     6  ...                 33.0                    16.0
# 36255             0    14  ...                 24.0                    26.0
# 36256             0    11  ...                 32.0                    21.0
# 36257             0    22  ...                 34.0                    17.0
# 36258             0    23  ...                 21.0                    24.0
#
#        away_standing_losses_home away_standing_points_home  \
# 36239                       10.0                    3115.0
# 36240                       14.0                    4996.0
# 36241                       12.0                    4306.0
# 36242                        4.0                    5469.0
# 36243                       14.0                    3302.0
# 36244                       13.0                    3960.0
# 36245                        5.0                    4127.0
# 36246                       12.0                    5639.0
# 36247                       14.0                    3191.0
# 36248                       12.0                    3349.0
# 36249                       19.0                    3292.0
# 36250                       13.0                    2639.0
# 36251                       11.0                    3278.0
# 36252                       12.0                    4306.0
# 36253                        7.0                    6985.0
# 36254                       13.0                    3960.0
# 36255                        5.0                    4132.0
# 36256                       10.0                    4532.0
# 36257                       14.0                    4996.0
# 36258                       10.0                    5850.0
#
#        away_standing_wins_away  away_standing_losses_away  \
# 36239                     11.0                       21.0
# 36240                     10.0                       20.0
# 36241                     10.0                       20.0
# 36242                     14.0                       16.0
# 36243                      9.0                       20.0
# 36244                     13.0                       19.0
# 36245                     16.0                       13.0
# 36246                     11.0                       18.0
# 36247                     11.0                       18.0
# 36248                     15.0                       15.0
# 36249                      5.0                       26.0
# 36250                     14.0                       19.0
# 36251                     16.0                       15.0
# 36252                     10.0                       21.0
# 36253                     12.0                       19.0
# 36254                     13.0                       20.0
# 36255                     10.0                       19.0
# 36256                      9.0                       22.0
# 36257                     11.0                       20.0
# 36258                     15.0                       11.0
#
#       away_standing_points_away  away_standing_diff  standing_diff  \
# 36239                    1208.0                -1.0           20.0
# 36240                    1125.0                -7.0            6.0
# 36241                    1177.0                -3.0            1.0
# 36242                    1619.0                22.0          -56.0
# 36243                    1053.0                -6.0            8.0
# 36244                    1604.0                -3.0           14.0
# 36245                    1887.0                24.0          -14.0
# 36246                    1310.0                 3.0           -4.0
# 36247                    1247.0                -4.0            5.0
# 36248                    1877.0                 6.0           -8.0
# 36249                     605.0               -29.0           25.0
# 36250                    1649.0                -4.0            5.0
# 36251                    1851.0                 9.0            4.0
# 36252                    1177.0                -4.0          -28.0
# 36253                    1362.0                12.0           16.0
# 36254                    1604.0                -4.0            1.0
# 36255                    1242.0                12.0          -47.0
# 36256                    1078.0                -2.0           -3.0
# 36257                    1226.0                -6.0           31.0
# 36258                    1764.0                18.0          -18.0
#
#       standing_points_diff
# 36239               4642.0
# 36240               3407.0
# 36241               2163.0
# 36242               -688.0
# 36243               3448.0
# 36244               2407.0
# 36245               1391.0
# 36246                414.0
# 36247               1686.0
# 36248               3480.0
# 36249               3857.0
# 36250               3422.0
# 36251               5743.0
# 36252               1950.0
# 36253               6989.0
# 36254               3753.0
# 36255               -311.0
# 36256               2113.0
# 36257               2901.0
# 36258               1351.0
#
# [20 rows x 76 columns]

# %%
target = 'home_win'
skip_cols = ['date', 'detail_path', 'team_pair', 'team_pair_sorted', 'winner', 'winner', 'hs', 'diff',
             'as', 'ot', 't1_wins_after_game', 't2_wins_after_game', 'leader_after_game', 'series_winner']

# %%
col_map = {}
for c in games_final.columns:
    if c not in skip_cols: col_map[c] = str(games_final[c].dtype)

# %%
for c in col_map.keys():
    if col_map[c] == 'object':
        games_final[c] =  encode_features(games_final[c])

# %%
games_final = games_final.fillna(0)

# %%
games_final = games_final[[c for c in games_final.columns if c not in skip_cols]]

# %%
games_final['standing_diff'] = np.where(games_final['standing_diff']<0, 0, np.where(games_final['standing_diff']<10, 1, 2))

# %%
for i, c in enumerate(games_final.columns):
    games_final[c] = standardize_features(games_final[c])
    games_final[c] = normalize_features(games_final[c])

# %% [markdown]
# #####
# ##### **SPLIT DATA**

# %%
val_frac = 0.1
test_frac = 0.1

train_frac = 1 - val_frac - test_frac
val_frac = train_frac + val_frac

# %%
np.random.seed(56)
games_final_shuffled = games_final.sample(frac=1).reset_index(drop=True)

# %%
games_final_shuffled #[-250:-230]
# Out:
#            away      home  game_type  game_subtype     month  home_win  \
# 0      0.000000  0.393939        1.0           0.0  0.000000       1.0
# 1      0.727273  0.757576        1.0           0.0  0.909091       1.0
# 2      0.696970  0.272727        1.0           0.0  0.090909       1.0
# 3      0.151515  0.909091        1.0           0.0  0.090909       1.0
# 4      0.484848  0.727273        1.0           0.0  0.181818       1.0
# ...         ...       ...        ...           ...       ...       ...
# 36334  0.636364  0.363636        1.0           0.0  0.181818       0.0
# 36335  0.363636  0.272727        0.5           0.0  0.818182       0.0
# 36336  0.212121  0.424242        1.0           0.0  0.272727       1.0
# 36337  0.212121  0.727273        1.0           0.0  0.090909       1.0
# 36338  0.848485  0.939394        0.5           0.0  0.818182       0.0
#
#          season  is_preseason  is_playoffs  t1_wins_before_game  ...  \
# 0      0.814815           0.0          0.0                  0.0  ...
# 1      0.148148           0.0          0.0                  0.0  ...
# 2      0.037037           0.0          0.0                  0.0  ...
# 3      0.962963           0.0          0.0                  0.0  ...
# 4      0.962963           0.0          0.0                  0.0  ...
# ...         ...           ...          ...                  ...  ...
# 36334  0.370370           0.0          0.0                  0.0  ...
# 36335  0.740741           1.0          0.0                  0.0  ...
# 36336  0.074074           0.0          0.0                  0.0  ...
# 36337  0.925926           0.0          0.0                  0.0  ...
# 36338  1.000000           1.0          0.0                  0.0  ...
#
#        away_standing_losses  away_standing_wins_home  \
# 0                  0.408451                    0.175
# 1                  0.014085                    0.000
# 2                  0.281690                    0.375
# 3                  0.253521                    0.475
# 4                  0.338028                    0.650
# ...                     ...                      ...
# 36334              0.605634                    0.275
# 36335              0.000000                    0.000
# 36336              0.873239                    0.325
# 36337              0.211268                    0.200
# 36338              0.000000                    0.000
#
#        away_standing_losses_home  away_standing_points_home  \
# 0                       0.323529                   0.094237
# 1                       0.000000                   0.000000
# 2                       0.235294                   0.196741
# 3                       0.176471                   0.266769
# 4                       0.264706                   0.352385
# ...                          ...                        ...
# 36334                   0.529412                   0.142300
# 36335                   0.000000                   0.000000
# 36336                   0.823529                   0.152692
# 36337                   0.235294                   0.110888
# 36338                   0.000000                   0.000000
#
#        away_standing_wins_away  away_standing_losses_away  \
# 0                     0.088235                   0.473684
# 1                     0.000000                   0.026316
# 2                     0.294118                   0.315789
# 3                     0.382353                   0.315789
# 4                     0.617647                   0.394737
# ...                        ...                        ...
# 36334                 0.147059                   0.657895
# 36335                 0.000000                   0.000000
# 36336                 0.176471                   0.894737
# 36337                 0.205882                   0.184211
# 36338                 0.000000                   0.000000
#
#        away_standing_points_away  away_standing_diff  standing_diff  \
# 0                       0.087349               0.336            1.0
# 1                       0.000000               0.480            0.5
# 2                       0.245482               0.528            1.0
# 3                       0.373996               0.600            0.0
# 4                       0.595131               0.672            0.0
# ...                          ...                 ...            ...
# 36334                   0.119729               0.272            1.0
# 36335                   0.000000               0.488            0.5
# 36336                   0.150853               0.144            1.0
# 36337                   0.209086               0.488            1.0
# 36338                   0.000000               0.488            0.5
#
#        standing_points_diff
# 0                  0.342974
# 1                  0.266660
# 2                  0.361638
# 3                  0.276138
# 4                  0.256498
# ...                     ...
# 36334              0.393004
# 36335              0.266660
# 36336              0.544557
# 36337              0.337796
# 36338              0.266660
#
# [36339 rows x 63 columns]

# %%
x_train = games_final_shuffled.iloc[:int(len(games_final)*train_frac),:]
x_val = games_final_shuffled.iloc[int(len(games_final)*train_frac):int(len(games_final)*val_frac),:]
x_test = games_final_shuffled.iloc[int(len(games_final)*val_frac):,:]

# %%
y_train = np.array(x_train.pop(target))
y_val = np.array(x_val.pop(target))
y_test = np.array(x_test.pop(target))

# %%
x_train, x_val, x_test = np.array(x_train), np.array(x_val), np.array(x_test)

# %%
# pickle splits for later
with open('../data/processed/games_split.pickle', 'wb') as f:
    pickle.dump(((x_train, x_val, x_test),(y_train, y_val, y_test)), f, pickle.HIGHEST_PROTOCOL)
s3_client.upload_file('../data/processed/games_split.pickle', 'hwm-nba', os.path.join('model_data', 'games_split.pickle'))

# %% [markdown]
# #####
# ##### **FIRST MODELS**

# %%
# set random seed
tf.random.set_seed(16)

# create the model
model_0 = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu'),
    # tf.keras.layers.Dropout(0.1), 
    tf.keras.layers.Dense(1, activation='sigmoid') # output shape is 1
])

# compile the model
model_0.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(5e-5),
    metrics=['accuracy']
)

# fit the model
history = model_0.fit(
    x_train,
    y_train,
    epochs=40,
    validation_data=(x_val, y_val)
) # see how the model performs on the test set during training

model_0_assets = {
    'model': model_0,
    'history': pd.DataFrame.from_dict(history.history),
    'name': 'model_'+str(int(datetime.datetime.now().timestamp()*100000))+'_'+str(history.history['val_accuracy'][-1])
}
# Out:
# Epoch 1/40
# 909/909 [==============================] - 3s 2ms/step - loss: 0.6887 - accuracy: 0.5619 - val_loss: 0.6611 - val_accuracy: 0.5960
# Epoch 2/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6425 - accuracy: 0.6261 - val_loss: 0.6377 - val_accuracy: 0.6307
# Epoch 3/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6258 - accuracy: 0.6502 - val_loss: 0.6295 - val_accuracy: 0.6445
# Epoch 4/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6192 - accuracy: 0.6552 - val_loss: 0.6267 - val_accuracy: 0.6489
# Epoch 5/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6163 - accuracy: 0.6586 - val_loss: 0.6258 - val_accuracy: 0.6502
# Epoch 6/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6148 - accuracy: 0.6590 - val_loss: 0.6252 - val_accuracy: 0.6494
# Epoch 7/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6138 - accuracy: 0.6615 - val_loss: 0.6248 - val_accuracy: 0.6513
# Epoch 8/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6133 - accuracy: 0.6624 - val_loss: 0.6244 - val_accuracy: 0.6522
# Epoch 9/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6126 - accuracy: 0.6618 - val_loss: 0.6244 - val_accuracy: 0.6486
# Epoch 10/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6122 - accuracy: 0.6627 - val_loss: 0.6237 - val_accuracy: 0.6516
# Epoch 11/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6118 - accuracy: 0.6637 - val_loss: 0.6238 - val_accuracy: 0.6472
# Epoch 12/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6115 - accuracy: 0.6642 - val_loss: 0.6235 - val_accuracy: 0.6486
# Epoch 13/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6112 - accuracy: 0.6638 - val_loss: 0.6232 - val_accuracy: 0.6491
# Epoch 14/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6109 - accuracy: 0.6640 - val_loss: 0.6229 - val_accuracy: 0.6547
# Epoch 15/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6108 - accuracy: 0.6648 - val_loss: 0.6225 - val_accuracy: 0.6513
# Epoch 16/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6106 - accuracy: 0.6645 - val_loss: 0.6226 - val_accuracy: 0.6555
# Epoch 17/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6103 - accuracy: 0.6646 - val_loss: 0.6227 - val_accuracy: 0.6505
# Epoch 18/40
# 909/909 [==============================] - 2s 3ms/step - loss: 0.6102 - accuracy: 0.6642 - val_loss: 0.6222 - val_accuracy: 0.6535
# Epoch 19/40
# 909/909 [==============================] - 3s 3ms/step - loss: 0.6100 - accuracy: 0.6650 - val_loss: 0.6220 - val_accuracy: 0.6544
# Epoch 20/40
# 909/909 [==============================] - 2s 3ms/step - loss: 0.6098 - accuracy: 0.6645 - val_loss: 0.6224 - val_accuracy: 0.6577
# Epoch 21/40
# 909/909 [==============================] - 2s 3ms/step - loss: 0.6098 - accuracy: 0.6652 - val_loss: 0.6219 - val_accuracy: 0.6524
# Epoch 22/40
# 909/909 [==============================] - 2s 3ms/step - loss: 0.6097 - accuracy: 0.6653 - val_loss: 0.6218 - val_accuracy: 0.6544
# Epoch 23/40
# 909/909 [==============================] - 2s 3ms/step - loss: 0.6095 - accuracy: 0.6649 - val_loss: 0.6217 - val_accuracy: 0.6541
# Epoch 24/40
# 909/909 [==============================] - 3s 3ms/step - loss: 0.6094 - accuracy: 0.6650 - val_loss: 0.6215 - val_accuracy: 0.6560
# Epoch 25/40
# 909/909 [==============================] - 2s 3ms/step - loss: 0.6092 - accuracy: 0.6657 - val_loss: 0.6220 - val_accuracy: 0.6577
# Epoch 26/40
# 909/909 [==============================] - 2s 3ms/step - loss: 0.6091 - accuracy: 0.6662 - val_loss: 0.6216 - val_accuracy: 0.6577
# Epoch 27/40
# 909/909 [==============================] - 2s 3ms/step - loss: 0.6092 - accuracy: 0.6659 - val_loss: 0.6214 - val_accuracy: 0.6538
# Epoch 28/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6089 - accuracy: 0.6661 - val_loss: 0.6217 - val_accuracy: 0.6483
# Epoch 29/40
# 909/909 [==============================] - 3s 3ms/step - loss: 0.6090 - accuracy: 0.6647 - val_loss: 0.6213 - val_accuracy: 0.6577
# Epoch 30/40
# 909/909 [==============================] - 3s 3ms/step - loss: 0.6089 - accuracy: 0.6662 - val_loss: 0.6211 - val_accuracy: 0.6558
# Epoch 31/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6088 - accuracy: 0.6654 - val_loss: 0.6213 - val_accuracy: 0.6585
# Epoch 32/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6087 - accuracy: 0.6650 - val_loss: 0.6214 - val_accuracy: 0.6580
# Epoch 33/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6086 - accuracy: 0.6656 - val_loss: 0.6211 - val_accuracy: 0.6588
# Epoch 34/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6086 - accuracy: 0.6661 - val_loss: 0.6211 - val_accuracy: 0.6585
# Epoch 35/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6085 - accuracy: 0.6656 - val_loss: 0.6209 - val_accuracy: 0.6555
# Epoch 36/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6085 - accuracy: 0.6663 - val_loss: 0.6209 - val_accuracy: 0.6585
# Epoch 37/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6084 - accuracy: 0.6657 - val_loss: 0.6208 - val_accuracy: 0.6591
# Epoch 38/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6084 - accuracy: 0.6658 - val_loss: 0.6209 - val_accuracy: 0.6585
# Epoch 39/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6083 - accuracy: 0.6676 - val_loss: 0.6207 - val_accuracy: 0.6585
# Epoch 40/40
# 909/909 [==============================] - 2s 2ms/step - loss: 0.6083 - accuracy: 0.6657 - val_loss: 0.6207 - val_accuracy: 0.6588

# %%
# set random seed
tf.random.set_seed(16)

# create the model
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu'),
    #tf.keras.layers.Dropout(0.1), 
    tf.keras.layers.Dense(32, activation='relu'),
    #tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(4, activation='relu'),
    #tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1, activation='sigmoid') # output shape is 1
])

# compile the model
model_1.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(1e-4),
    metrics=['accuracy']
)

# fit the model
history = model_1.fit(
    x_train,
    y_train,
    epochs=40,
    validation_data=(x_val, y_val)
) # see how the model performs on the test set during training

model_1_assets = {
    'model': model_1,
    'history': pd.DataFrame.from_dict(history.history),
    'name': 'model_'+str(int(datetime.datetime.now().timestamp()*100000))+'_'+str(history.history['val_accuracy'][-1])
}

# %%
# Set random seed
tf.random.set_seed(16)

# Create the model
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1), 
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1), 
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1), 
    tf.keras.layers.Dense(256, activation='selu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1), 
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid') # output shape is 1
])

# Compile the model
model_2.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(1e-3),
    metrics=['accuracy']
)

# Fit the model
history = model_2.fit(
    x_train,
    y_train,
    epochs=20,
    validation_data=(x_val, y_val)) # see how the model performs on the test set during training

model_2_assets = {
    'model': model_2,
    'history': pd.DataFrame.from_dict(history.history),
    'name': 'model_'+str(int(datetime.datetime.now().timestamp()*100000))+'_'+str(history.history['val_accuracy'][-1])
}
# Out:
# Epoch 1/20
# 904/904 [==============================] - 19s 20ms/step - loss: 0.6660 - accuracy: 0.6303 - val_loss: 0.6247 - val_accuracy: 0.6599
# Epoch 2/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6299 - accuracy: 0.6492 - val_loss: 0.6185 - val_accuracy: 0.6599
# Epoch 3/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6245 - accuracy: 0.6549 - val_loss: 0.6224 - val_accuracy: 0.6635
# Epoch 4/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6225 - accuracy: 0.6586 - val_loss: 0.6063 - val_accuracy: 0.6682
# Epoch 5/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6202 - accuracy: 0.6574 - val_loss: 0.6388 - val_accuracy: 0.6339
# Epoch 6/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6191 - accuracy: 0.6589 - val_loss: 0.6131 - val_accuracy: 0.6577
# Epoch 7/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6187 - accuracy: 0.6597 - val_loss: 0.6094 - val_accuracy: 0.6671
# Epoch 8/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6161 - accuracy: 0.6592 - val_loss: 0.6063 - val_accuracy: 0.6660
# Epoch 9/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6152 - accuracy: 0.6609 - val_loss: 0.6044 - val_accuracy: 0.6680
# Epoch 10/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6144 - accuracy: 0.6631 - val_loss: 0.6076 - val_accuracy: 0.6666
# Epoch 11/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6152 - accuracy: 0.6608 - val_loss: 0.6065 - val_accuracy: 0.6644
# Epoch 12/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6149 - accuracy: 0.6608 - val_loss: 0.6061 - val_accuracy: 0.6682
# Epoch 13/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6143 - accuracy: 0.6621 - val_loss: 0.6084 - val_accuracy: 0.6630
# Epoch 14/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6149 - accuracy: 0.6600 - val_loss: 0.6084 - val_accuracy: 0.6610
# Epoch 15/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6140 - accuracy: 0.6609 - val_loss: 0.6092 - val_accuracy: 0.6657
# Epoch 16/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6144 - accuracy: 0.6624 - val_loss: 0.6051 - val_accuracy: 0.6674
# Epoch 17/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6135 - accuracy: 0.6625 - val_loss: 0.6045 - val_accuracy: 0.6649
# Epoch 18/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6133 - accuracy: 0.6615 - val_loss: 0.6075 - val_accuracy: 0.6702
# Epoch 19/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6130 - accuracy: 0.6627 - val_loss: 0.6086 - val_accuracy: 0.6652
# Epoch 20/20
# 904/904 [==============================] - 18s 20ms/step - loss: 0.6129 - accuracy: 0.6608 - val_loss: 0.6075 - val_accuracy: 0.6710

# %%
# Set random seed
tf.random.set_seed(16)

# Create the model
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(2, activation='relu'),
    tf.keras.layers.Dense(1) # output shape is 1
])

# Compile the model
model_3.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(5e-4),
    metrics=['accuracy']
)

# Fit the model
history = model_3.fit(
    x_train,
    y_train,
    epochs=20,
    validation_data=(x_test,y_test),
    #verbose=1,
    #callbacks=[PrintDot()]
)
# see how the model performs on the test set during training

model_3_assets = {
    'model': model_3,
    'history': pd.DataFrame.from_dict(history.history),
    'name': 'model_'+str(int(datetime.datetime.now().timestamp()*100000))+'_'+str(history.history['val_accuracy'][-1])
}
# Out:
# Epoch 1/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.8914 - accuracy: 0.5436 - val_loss: 0.6795 - val_accuracy: 0.5908
# Epoch 2/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6666 - accuracy: 0.6035 - val_loss: 0.6512 - val_accuracy: 0.6154
# Epoch 3/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6470 - accuracy: 0.6265 - val_loss: 0.6445 - val_accuracy: 0.6287
# Epoch 4/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6362 - accuracy: 0.6415 - val_loss: 0.6334 - val_accuracy: 0.6317
# Epoch 5/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6302 - accuracy: 0.6491 - val_loss: 0.6301 - val_accuracy: 0.6408
# Epoch 6/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6263 - accuracy: 0.6523 - val_loss: 0.6281 - val_accuracy: 0.6408
# Epoch 7/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6233 - accuracy: 0.6558 - val_loss: 0.6251 - val_accuracy: 0.6505
# Epoch 8/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6221 - accuracy: 0.6579 - val_loss: 0.6244 - val_accuracy: 0.6497
# Epoch 9/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6204 - accuracy: 0.6579 - val_loss: 0.6249 - val_accuracy: 0.6453
# Epoch 10/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6192 - accuracy: 0.6606 - val_loss: 0.6217 - val_accuracy: 0.6547
# Epoch 11/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6182 - accuracy: 0.6589 - val_loss: 0.6235 - val_accuracy: 0.6508
# Epoch 12/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6194 - accuracy: 0.6608 - val_loss: 0.6233 - val_accuracy: 0.6525
# Epoch 13/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6175 - accuracy: 0.6627 - val_loss: 0.6223 - val_accuracy: 0.6561
# Epoch 14/20
# 904/904 [==============================] - 4s 5ms/step - loss: 0.6175 - accuracy: 0.6618 - val_loss: 0.6224 - val_accuracy: 0.6544
# Epoch 15/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6179 - accuracy: 0.6596 - val_loss: 0.6204 - val_accuracy: 0.6525
# Epoch 16/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6161 - accuracy: 0.6619 - val_loss: 0.6225 - val_accuracy: 0.6541
# Epoch 17/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6182 - accuracy: 0.6596 - val_loss: 0.6667 - val_accuracy: 0.5930
# Epoch 18/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6185 - accuracy: 0.6596 - val_loss: 0.6202 - val_accuracy: 0.6569
# Epoch 19/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6151 - accuracy: 0.6612 - val_loss: 0.6227 - val_accuracy: 0.6544
# Epoch 20/20
# 904/904 [==============================] - 5s 5ms/step - loss: 0.6156 - accuracy: 0.6633 - val_loss: 0.6220 - val_accuracy: 0.6558

# %%
# Set random seed
tf.random.set_seed(16)

# Create the model
model_4 = tf.keras.Sequential([
    tf.keras.layers.Dense(1) # output shape is 1
])

# Compile the model
model_4.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(5e-4),
    metrics=['accuracy']
)

# Fit the model
history = model_4.fit(
    x_train,
    y_train,
    epochs=1,
    validation_data=(x_test,y_test),
    # verbose=1,
    # callbacks=[PrintDot()]
)
# see how the model performs on the test set during training

model_4_assets = {
    'model': model_4,
    'history': pd.DataFrame.from_dict(history.history),
    'name': 'model_'+str(int(datetime.datetime.now().timestamp()*100000))+'_'+str(history.history['val_accuracy'][-1])
}
# Out:
# 904/904 [==============================] - 5s 5ms/step - loss: 1.4123 - accuracy: 0.4815 - val_loss: 0.8097 - val_accuracy: 0.5177

# %% [markdown]
# #####
# ##### **UPLOAD TO RELEVANT AWS RESOURCES (S3 AND SAGEMAKER)**

# %%
with open('../sagemaker/params.json','r') as params:
    params = json.load(params)

# %%
key_data = x_train[:1000]

# %%
# TODO: reflect more on the right nomenclature inside sagemaker
save_and_package_model(model_0_assets, '../models', sagemaker_name='model-0', key_data=key_data)
save_and_package_model(model_1_assets, '../models', sagemaker_name='model-1', key_data=key_data)
save_and_package_model(model_2_assets, '../models', sagemaker_name='model-2', key_data=key_data)
save_and_package_model(model_3_assets, '../models', sagemaker_name='model-3', key_data=key_data)
save_and_package_model(model_4_assets, '../models', sagemaker_name='model-4', key_data=key_data)
# Out:
# INFO:tensorflow:Assets written to: ../models/model_167654828573204_0.6701715588569641/00001/assets
# INFO:tensorflow:Assets written to: ../models/model_167654828573204_0.6701715588569641/00001/assets
# Adding ../models/model_167654828573204_0.6701715588569641/00001...
# Adding ../models/model_167654828573204_0.6701715588569641/history.csv...
# Adding ../models/model_167654828573204_0.6701715588569641/model.tar.gz...
# 32/32 [==============================] - 0s 1ms/step
# INFO:tensorflow:Assets written to: ../models/model_167654849883550_0.6651909351348877/00001/assets
# INFO:tensorflow:Assets written to: ../models/model_167654849883550_0.6651909351348877/00001/assets
# Adding ../models/model_167654849883550_0.6651909351348877/00001...
# Adding ../models/model_167654849883550_0.6651909351348877/history.csv...
# Adding ../models/model_167654849883550_0.6651909351348877/model.tar.gz...
# 32/32 [==============================] - 0s 2ms/step
# INFO:tensorflow:Assets written to: ../models/model_167654885970443_0.671001672744751/00001/assets
# INFO:tensorflow:Assets written to: ../models/model_167654885970443_0.671001672744751/00001/assets
# Adding ../models/model_167654885970443_0.671001672744751/00001...
# Adding ../models/model_167654885970443_0.671001672744751/history.csv...
# Adding ../models/model_167654885970443_0.671001672744751/model.tar.gz...
# 32/32 [==============================] - 0s 4ms/step
# INFO:tensorflow:Assets written to: ../models/model_167654895178177_0.6557831168174744/00001/assets
# INFO:tensorflow:Assets written to: ../models/model_167654895178177_0.6557831168174744/00001/assets
# Adding ../models/model_167654895178177_0.6557831168174744/00001...
# Adding ../models/model_167654895178177_0.6557831168174744/history.csv...
# Adding ../models/model_167654895178177_0.6557831168174744/model.tar.gz...
# 32/32 [==============================] - 0s 1ms/step
# INFO:tensorflow:Assets written to: ../models/model_167654895642998_0.517708957195282/00001/assets
# INFO:tensorflow:Assets written to: ../models/model_167654895642998_0.517708957195282/00001/assets
# Adding ../models/model_167654895642998_0.517708957195282/00001...
# Adding ../models/model_167654895642998_0.517708957195282/history.csv...
# Adding ../models/model_167654895642998_0.517708957195282/model.tar.gz...
# 32/32 [==============================] - 0s 1ms/step
